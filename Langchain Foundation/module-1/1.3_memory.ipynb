# %%
from langchain_classic.chains.qa_with_sources.map_reduce_prompt import question_prompt_template
from langchain_ollama import ChatOllama
from langchain.agents import create_agent
from langchain_core.tools import tool
from langchain_community.tools import DuckDuckGoSearchRun
from langgraph.checkpoint.memory import InMemorySaver
from langchain.messages import HumanMessage
from pprint import pprint

# %%
model = ChatOllama(model='gemma4:e4b', temperature=0)
agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),
)

# %%
question = HumanMessage(content="Hello my name is seaum and i am 21 years old. my favorite color is blue.")
response = agent.invoke(
    {'messages':[question]},
    config={'configurable':{'thread_id': '1'}}
)

# %%
print(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is seaum and i am 21 years old. my favorite color is blue.', additional_kwargs={}, response_metadata={}, id='6d5f3ade-ebcd-44b9-bc27-779688c97a2f'), AIMessage(content="Hello Seaum! It's very nice to meet you. 😊\n\nThanks for sharing that! Blue is a beautiful color—it's often associated with calmness and tranquility.\n\nHow can I help you today?", additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-05-26T15:18:39.5464724Z', 'done': True, 'done_reason': 'stop', 'total_duration': 49400037600, 'load_duration': 13042428000, 'prompt_eval_count': 37, 'prompt_eval_duration': 4178287600, 'eval_count': 333, 'eval_duration': 31521882900, 'logprobs': None, 'model_name': 'gemma4:e4b', 'model_provider': 'ollama'}, id='lc_run--019e64dd-11bb-7f80-a27a-732f968884c6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 333, 'total_tokens': 370})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config={'configurable':{'thread_id': '1'}},
)

pprint(response['messages'][-1].content)
# Out:
# 'You told me that your favorite color is **blue**! 💙'
