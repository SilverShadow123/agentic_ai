# %%
# !pip install pywin32
# Out:
# Requirement already satisfied: pywin32 in C:\Users\Sunan\PycharmProjects\agentic_ai\.venv\Lib\site-packages (311)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_ollama import ChatOllama
from langchain.agents import create_agent

# %%
model = ChatOllama(
    model='gemma4:e4b',
)

# %%
import sys
import subprocess

code = """
import asyncio
from langchain_mcp_adapters.client import MultiServerMCPClient

async def main():
    mcp_client = MultiServerMCPClient(
        {
            "time": {
                "transport": "stdio",
                "command": "npx",
                "args": ["-y", "@dandeliongold/mcp-time"],
            }
        }
    )
    mcp_tools = await mcp_client.get_tools()
    print(f"Loaded {len(mcp_tools)} MCP tools: {[t.name for t in mcp_tools]}")

asyncio.run(main())
"""

result = subprocess.run(
    [sys.executable, "-c", code],
    capture_output=True,
    text=True
)

print("STDOUT:", result.stdout)
print("STDERR:", result.stderr)
# Out:
# STDOUT: Loaded 2 MCP tools: ['getCurrentTime', 'getTimeDifference']
#
# STDERR: Time server running on stdio

# %%
# Out:
# ---------------------------------------------------------------------------
# NoEventLoopError                          Traceback (most recent call last)
# File ~\PycharmProjects\agentic_ai\.venv\Lib\site-packages\mcp\os\win32\utilities.py:169, in create_windows_process(command, args, env, errlog, cwd)
#     167 try:
#     168     # First try using anyio with Windows-specific flags to hide console window
# --> 169     process = await anyio.open_process(
#     170         [command, *args],
#     171         env=env,
#     172         # Ensure we don't create console windows for each process
#     173         creationflags=subprocess.CREATE_NO_WINDOW  # type: ignore
#     174         if hasattr(subprocess, "CREATE_NO_WINDOW")
#     175         else 0,
#     176         stderr=errlog,
#     177         cwd=cwd,
#     178     )
#     179 except NotImplementedError:
#     180     # If Windows doesn't support async subprocess creation, use fallback
#
# File ~\PycharmProjects\agentic_ai\.venv\Lib\site-packages\anyio\_core\_subprocesses.py:184, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     182     kwargs["umask"] = umask
# --> 184 return await get_async_backend().open_process(
#     185     command,
#     186     stdin=stdin,
#     187     stdout=stdout,
#     188     stderr=stderr,
#     189     cwd=cwd,
#     190     env=env,
#     191     startupinfo=startupinfo,
#     192     creationflags=creationflags,
#     193     start_new_session=start_new_session,
#     194     pass_fds=pass_fds,
#     195     **kwargs,
#     196 )
#
# File ~\PycharmProjects\agentic_ai\.venv\Lib\site-packages\anyio\_core\_eventloop.py:189, in get_async_backend(asynclib_name)
#     188     if not asynclib_name:
# --> 189         raise NoEventLoopError(
#     190             f"Not currently running on any asynchronous event loop. "
#     191             f"Available async backends: {', '.join(get_all_backends())}"
#     192         )
#     194 # We use our own dict instead of sys.modules to get the already imported back-end
#     195 # class because the appropriate modules in sys.modules could potentially be only
#     196 # partially initialized
#
# NoEventLoopError: Not currently running on any asynchronous event loop. Available async backends: asyncio, trio
#
# During handling of the above exception, another exception occurred:
#
# NoEventLoopError                          Traceback (most recent call last)
# Cell In[12], line 20
#      16     },
#      17 )
#      18
#      19 # Load tools from the MCP server
# ---> 20 mcp_tools = await mcp_client.get_tools()
#      21 print(f"Loaded {len(mcp_tools)} MCP tools: {[t.name for t in mcp_tools]}")
#
# File ~\PycharmProjects\agentic_ai\.venv\Lib\site-packages\langchain_mcp_adapters\client.py:197, in MultiServerMCPClient.get_tools(self, server_name)
#     186     load_mcp_tool_task = asyncio.create_task(
#     187         load_mcp_tools(
#     188             None,
#    (...)    194         )
#     195     )
#     196     load_mcp_tool_tasks.append(load_mcp_tool_task)
# --> 197 tools_list = await asyncio.gather(*load_mcp_tool_tasks)
#     198 for tools in tools_list:
#     199     all_tools.extend(tools)
#
# File C:\Python314\Lib\asyncio\tasks.py:362, in Task.__wakeup(self, future)
#     360 futures.future_discard_from_awaited_by(future, self)
#     361 try:
# --> 362     future.result()
#     363 except BaseException as exc:
#     364     # This may also be a cancellation.
#     365     self.__step(exc)
#
# File C:\Python314\Lib\asyncio\tasks.py:289, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     285 try:
#     286     if exc is None:
#     287         # We use the `send` method directly, because coroutines
#     288         # don't have `__iter__` and `__next__` methods.
# --> 289         result = coro.send(None)
#     290     else:
#     291         result = coro.throw(exc)
#
# File ~\PycharmProjects\agentic_ai\.venv\Lib\site-packages\langchain_mcp_adapters\tools.py:478, in load_mcp_tools(session, connection, callbacks, tool_interceptors, server_name, tool_name_prefix)
#     476     msg = "Either session or connection must be provided"
#     477     raise ValueError(msg)
# --> 478 async with create_session(
#     479     connection, mcp_callbacks=mcp_callbacks
#     480 ) as tool_session:
#     481     await tool_session.initialize()
#     482     tools = await _list_all_tools(tool_session)
#
# File C:\Python314\Lib\contextlib.py:214, in _AsyncGeneratorContextManager.__aenter__(self)
#     212 del self.args, self.kwds, self.func
#     213 try:
# --> 214     return await anext(self.gen)
#     215 except StopAsyncIteration:
#     216     raise RuntimeError("generator didn't yield") from None
#
# File ~\PycharmProjects\agentic_ai\.venv\Lib\site-packages\langchain_mcp_adapters\sessions.py:457, in create_session(connection, mcp_callbacks)
#     455         msg = "'args' parameter is required for stdio connection"
#     456         raise ValueError(msg)
# --> 457     async with _create_stdio_session(**params) as session:
#     458         yield session
#     459 elif transport == "websocket":
#
# File C:\Python314\Lib\contextlib.py:214, in _AsyncGeneratorContextManager.__aenter__(self)
#     212 del self.args, self.kwds, self.func
#     213 try:
# --> 214     return await anext(self.gen)
#     215 except StopAsyncIteration:
#     216     raise RuntimeError("generator didn't yield") from None
#
# File ~\PycharmProjects\agentic_ai\.venv\Lib\site-packages\langchain_mcp_adapters\sessions.py:269, in _create_stdio_session(command, args, env, cwd, encoding, encoding_error_handler, session_kwargs)
#     258 server_params = StdioServerParameters(
#     259     command=command,
#     260     args=args,
#    (...)    264     encoding_error_handler=encoding_error_handler,
#     265 )
#     267 # Create and store the connection
#     268 async with (
# --> 269     stdio_client(server_params) as (read, write),
#     270     ClientSession(read, write, **(session_kwargs or {})) as session,
#     271 ):
#     272     yield session
#
# File C:\Python314\Lib\contextlib.py:214, in _AsyncGeneratorContextManager.__aenter__(self)
#     212 del self.args, self.kwds, self.func
#     213 try:
# --> 214     return await anext(self.gen)
#     215 except StopAsyncIteration:
#     216     raise RuntimeError("generator didn't yield") from None
#
# File ~\PycharmProjects\agentic_ai\.venv\Lib\site-packages\mcp\client\stdio\__init__.py:124, in stdio_client(server, errlog)
#     121     command = _get_executable_command(server.command)
#     123     # Open process with stderr piped for capture
# --> 124     process = await _create_platform_compatible_process(
#     125         command=command,
#     126         args=server.args,
#     127         env=({**get_default_environment(), **server.env} if server.env is not None else get_default_environment()),
#     128         errlog=errlog,
#     129         cwd=server.cwd,
#     130     )
#     131 except OSError:
#     132     # Clean up streams if process creation fails
#     133     await read_stream.aclose()
#
# File ~\PycharmProjects\agentic_ai\.venv\Lib\site-packages\mcp\client\stdio\__init__.py:249, in _create_platform_compatible_process(command, args, env, errlog, cwd)
#     242 """
#     243 Creates a subprocess in a platform-compatible way.
#     244
#     245 Unix: Creates process in a new session/process group for killpg support
#     246 Windows: Creates process in a Job Object for reliable child termination
#     247 """
#     248 if sys.platform == "win32":  # pragma: no cover
# --> 249     process = await create_windows_process(command, args, env, errlog, cwd)
#     250 else:
#     251     process = await anyio.open_process(
#     252         [command, *args],
#     253         env=env,
#    (...)    256         start_new_session=True,
#     257     )  # pragma: no cover
#
# File ~\PycharmProjects\agentic_ai\.venv\Lib\site-packages\mcp\os\win32\utilities.py:184, in create_windows_process(command, args, env, errlog, cwd)
#     181     process = await _create_windows_fallback_process(command, args, env, errlog, cwd)
#     182 except Exception:
#     183     # Try again without creation flags
# --> 184     process = await anyio.open_process(
#     185         [command, *args],
#     186         env=env,
#     187         stderr=errlog,
#     188         cwd=cwd,
#     189     )
#     191 _maybe_assign_process_to_job(process, job)
#     192 return process
#
# File ~\PycharmProjects\agentic_ai\.venv\Lib\site-packages\anyio\_core\_subprocesses.py:184, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     181 if umask >= 0:
#     182     kwargs["umask"] = umask
# --> 184 return await get_async_backend().open_process(
#     185     command,
#     186     stdin=stdin,
#     187     stdout=stdout,
#     188     stderr=stderr,
#     189     cwd=cwd,
#     190     env=env,
#     191     startupinfo=startupinfo,
#     192     creationflags=creationflags,
#     193     start_new_session=start_new_session,
#     194     pass_fds=pass_fds,
#     195     **kwargs,
#     196 )
#
# File ~\PycharmProjects\agentic_ai\.venv\Lib\site-packages\anyio\_core\_eventloop.py:189, in get_async_backend(asynclib_name)
#     187     asynclib_name = current_async_library()
#     188     if not asynclib_name:
# --> 189         raise NoEventLoopError(
#     190             f"Not currently running on any asynchronous event loop. "
#     191             f"Available async backends: {', '.join(get_all_backends())}"
#     192         )
#     194 # We use our own dict instead of sys.modules to get the already imported back-end
#     195 # class because the appropriate modules in sys.modules could potentially be only
#     196 # partially initialized
#     197 try:
#
# NoEventLoopError: Not currently running on any asynchronous event loop. Available async backends: asyncio, trio
